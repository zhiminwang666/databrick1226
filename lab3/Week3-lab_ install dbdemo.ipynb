# %% [markdown]
# must create main catalog first

# %%
# %pip install dbdemos

# %%
# %restart_python

# %%
import dbdemos
dbdemos.install('data-ingestion')

# %%
dbdemos.create_cluster('data-ingestion')

# %%
import dbdemos
dbdemos.install('pipeline-bike', catalog='main', schema='dbdemos_pipeline_bike')
